# %%
# %matplotlib inline
# %run Plotter.py
# Out:
# SCORE: 0.9815547646800982
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Documents\00 - School\Vic\3rd Year\3-2\COMP309\Ass2\Plotter.py in <module>()
#     119
#     120 if __name__ == "__main__":
# --> 121     main()
#
# ~\Documents\00 - School\Vic\3rd Year\3-2\COMP309\Ass2\Plotter.py in main()
#      31
#      32     # Finally, plot regression
# ---> 33     regplot = plot_regression(df, predicted)
#      34     # xticks = ax.get_xticks()
#      35     # ax.set_xticklabels([pd.to_datetime(tick).strftime("%Y") for tick in xticks])
#
# ~\Documents\00 - School\Vic\3rd Year\3-2\COMP309\Ass2\Plotter.py in plot_regression(df, predicted)
#     103         robust=True,
#     104         truncate=False,
# --> 105         marker='d'
#     106     )
#     107     ax.xaxis.set_major_formatter(date_display_from_float)
#
# ...
